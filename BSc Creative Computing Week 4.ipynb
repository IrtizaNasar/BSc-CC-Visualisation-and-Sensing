# %% [markdown]
# # Week 3 - Introduction to Pandas

# %% [markdown]
# ## Installing and importing a python package/library

# %% [markdown]
# - Installing Pandas Library for Data Processing
# - What is Pandas?
#     - Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#     - Its main data format is the DataFrame, which is like a 2D array, but with column names and indexes for the rows.
#     - It is essentially the swiss army knife for your data. Using pandas, you get better undertand your data by cleaning, transforming, and analyzing it.
#
#     - For example, say you want to explore a dataset stored in a CSV on your computer. Pandas will extract the data from that CSV into a DataFrame — a table, basically — then let you do things like:
#       - Calculate statistics and answer questions about the data, like
#       - What's the average, median, max, or min of each column?
#       - Does column A correlate with column B?
#       - What does the distribution of data in column C look like?
#       - Clean the data by doing things like removing missing values and filtering rows or columns by some criteria
#       - Store the cleaned, transformed data back into a CSV, other file or database
#
# - Before you start visualizing data you need to have a good understanding of the nature of your dataset and pandas is the best package to do that.

# %% [markdown]
# ### Using pip to install Pandas

# %%
# Need to only be run once per environment. No need to run it again in every project.

import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/Caskroom/miniforge/base/envs/cci/lib/python3.8/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cci/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/cci/lib/python3.8/site-packages (from pandas) (2022.5)
# Requirement already satisfied: numpy>=1.20.3 in /opt/homebrew/Caskroom/miniforge/base/envs/cci/lib/python3.8/site-packages (from pandas) (1.23.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/cci/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %% [markdown]
# ### Importing pandas package library

# %%
# Imprting pandas library as pd so instead of wrting pandas everywhere we can call pd which is shorter
import pandas as pd

# %% [markdown]
# ## Creating DataFrame from Scratch

# %% [markdown]
# There are many ways to create a DataFrame from scratch, but to start with lets use a simple dictionary.
#
# Let's say we have a fruit stand that sells apples and oranges. We want to have a column for each fruit and a row for each customer purchase. To organize this as a dictionary for pandas we could do something like:
#
# Scratch Data Frame Example Adapated from https://www.learndatasci.com/tutorials/python-pandas-tutorial-complete-introduction-for-beginners/

# %% [markdown]
# A dictionary is a collection which is ordered, changeable and do not allow duplicates.
#
# For more on dictiornay, arrys and list read here https://python.plainenglish.io/arrays-vs-list-vs-dictionaries-47058fa19d4e

# %%
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}

# %%
data
# Out:
# {'apples': [3, 2, 0, 1], 'oranges': [0, 3, 7, 2]}

# %% [markdown]
# And then pass it to the pandas DataFrame constructor:

# %%
purchases = pd.DataFrame(data)

purchases
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       1        2

# %% [markdown]
# How did that work?
# Each (key, value) item in data corresponds to a column in the resulting DataFrame.
#
# The Index of this DataFrame was given to us on creation as the numbers 0-3, but we could also create our own when we initialize the DataFrame.
#
# Let's have customer names as our index:

# %%
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])

purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %% [markdown]
# So now we could locate a customer's order by using their name:

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %% [markdown]
# ## Converting back to a CSV, JSON

# %% [markdown]
# Pandas provides intuitive commands to save your cleaned data in a file of your choice. They are similar to the way we read the data:
#
# When we save JSON and CSV files, all we have to input into those functions is our desired filename with the appropriate file extension.

# %%
# purchases.to_csv('new_purchases.csv')

# purchases.to_json('new_purchases.json')

# %% [markdown]
# ## Loading and exploring data with Pandas

# %% [markdown]
# First we load in the data. This particular dataset is from [IMDB (Internet Movie Database)](https://www.kaggle.com/datasets/mustafacicek/imdb-top-250-lists-1996-2020?resource=download) and is in the **comma-separated variable (.csv)** format.
#
# ``
# df = pd.read_csv("data/imdbTop250.csv")
# ``
#
# Pandas shows us the **head** (first rows) and the **tail** (last rows), as well as the **shape**. So we know there are 16 columns (separate pieces of info about each film), and 6500 films.

# %%
#load
#pd.options.display.max_rows = 100
df = pd.read_csv("data/imdbTop250.csv")

# %%
df
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# 6495               The Battle of Algiers  1966      121
# 6496                   Nights of Cabiria  1957      110
# 6497                  The Princess Bride  1987       98
# 6498                          Raatchasan  2018      170
# 6499                        Sardar Udham  2021      164
#
#                            Genre  Rating  Score    Votes   Gross  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1                          Drama     9.3   80.0  2529673   28.34
# 2                          Drama     8.1   83.0   665213   16.50
# 3          Crime, Drama, Mystery     8.5   77.0  1045626   23.34
# 4       Animation, Short, Comedy     8.3    NaN    53316     NaN
# ...                          ...     ...    ...      ...     ...
# 6495                  Drama, War     8.1   96.0    57995    0.06
# 6496                       Drama     8.1    NaN    47318    0.75
# 6497  Adventure, Family, Fantasy     8.1   77.0   416207   30.86
# 6498       Crime, Drama, Mystery     8.4    NaN    37474     NaN
# 6499     Biography, Crime, Drama     8.7    NaN    34889     NaN
#
#               Director              Cast1              Cast2  \
# 0         George Lucas        Mark Hamill      Harrison Ford
# 1       Frank Darabont        Tim Robbins     Morgan Freeman
# 2          Danny Boyle      Ewan McGregor       Ewen Bremner
# 3         Bryan Singer       Kevin Spacey      Gabriel Byrne
# 4            Nick Park       Peter Sallis      Peter Hawkins
# ...                ...                ...                ...
# 6495  Gillo Pontecorvo     Brahim Hadjadj        Jean Martin
# 6496  Federico Fellini   Giulietta Masina    François Périer
# 6497        Rob Reiner         Cary Elwes     Mandy Patinkin
# 6498         Ram Kumar      Vishnu Vishal         Amala Paul
# 6499    Shoojit Sircar      Vicky Kaushal      Banita Sandhu
#
#                    Cast3              Cast4
# 0          Carrie Fisher      Alec Guinness
# 1             Bob Gunton     William Sadler
# 2       Jonny Lee Miller       Kevin McKidd
# 3       Chazz Palminteri    Stephen Baldwin
# 4                    NaN                NaN
# ...                  ...                ...
# 6495         Yacef Saadi      Samia Kerbash
# 6496        Franca Marzi        Dorian Gray
# 6497        Robin Wright     Chris Sarandon
# 6498          Radha Ravi    Sangili Murugan
# 6499         Shaun Scott      Stephen Hogan
#
# [6500 rows x 16 columns]

# %%
# Standard format is rows x colums
# Hence our dataset has 6500 rows and 16 colums
df.shape
# Out:
# (6500, 16)

# %%
df
# Out:
#       Ranking  IMDByear            IMDBlink  \
# 0           1      1996   /title/tt0076759/
# 1           2      1996   /title/tt0111161/
# 2           3      1996   /title/tt0117951/
# 3           4      1996   /title/tt0114814/
# 4           5      1996   /title/tt0108598/
# ...       ...       ...                 ...
# 6495      246      2021   /title/tt0058946/
# 6496      247      2021   /title/tt0050783/
# 6497      248      2021   /title/tt0093779/
# 6498      249      2021   /title/tt7060344/
# 6499      250      2021  /title/tt10280296/
#
#                                    Title  Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope  1977      121
# 1               The Shawshank Redemption  1994      142
# 2                          Trainspotting  1996       93
# 3                     The Usual Suspects  1995      106
# 4                     The Wrong Trousers  1993       30
# ...                                  ...   ...      ...
# 6495               The Battle of Algiers  1966      121
# 6496                   Nights of Cabiria  1957      110
# 6497                  The Princess Bride  1987       98
# 6498                          Raatchasan  2018      170
# 6499                        Sardar Udham  2021      164
#
#                            Genre  Rating  Score    Votes   Gross  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1                          Drama     9.3   80.0  2529673   28.34
# 2                          Drama     8.1   83.0   665213   16.50
# 3          Crime, Drama, Mystery     8.5   77.0  1045626   23.34
# 4       Animation, Short, Comedy     8.3    NaN    53316     NaN
# ...                          ...     ...    ...      ...     ...
# 6495                  Drama, War     8.1   96.0    57995    0.06
# 6496                       Drama     8.1    NaN    47318    0.75
# 6497  Adventure, Family, Fantasy     8.1   77.0   416207   30.86
# 6498       Crime, Drama, Mystery     8.4    NaN    37474     NaN
# 6499     Biography, Crime, Drama     8.7    NaN    34889     NaN
#
#               Director              Cast1              Cast2  \
# 0         George Lucas        Mark Hamill      Harrison Ford
# 1       Frank Darabont        Tim Robbins     Morgan Freeman
# 2          Danny Boyle      Ewan McGregor       Ewen Bremner
# 3         Bryan Singer       Kevin Spacey      Gabriel Byrne
# 4            Nick Park       Peter Sallis      Peter Hawkins
# ...                ...                ...                ...
# 6495  Gillo Pontecorvo     Brahim Hadjadj        Jean Martin
# 6496  Federico Fellini   Giulietta Masina    François Périer
# 6497        Rob Reiner         Cary Elwes     Mandy Patinkin
# 6498         Ram Kumar      Vishnu Vishal         Amala Paul
# 6499    Shoojit Sircar      Vicky Kaushal      Banita Sandhu
#
#                    Cast3              Cast4
# 0          Carrie Fisher      Alec Guinness
# 1             Bob Gunton     William Sadler
# 2       Jonny Lee Miller       Kevin McKidd
# 3       Chazz Palminteri    Stephen Baldwin
# 4                    NaN                NaN
# ...                  ...                ...
# 6495         Yacef Saadi      Samia Kerbash
# 6496        Franca Marzi        Dorian Gray
# 6497        Robin Wright     Chris Sarandon
# 6498          Radha Ravi    Sangili Murugan
# 6499         Shaun Scott      Stephen Hogan
#
# [6500 rows x 16 columns]

# %%
# Let's say we want to just peak at the first five rows of our dataset we can then use .head()
# Since our dataframe is in the varaible df we are asking it to show us the first five rows using df.head(5)

df.head(5)
# Out:
#    Ranking  IMDByear           IMDBlink                               Title  \
# 0        1      1996  /title/tt0076759/  Star Wars: Episode IV - A New Hope
# 1        2      1996  /title/tt0111161/            The Shawshank Redemption
# 2        3      1996  /title/tt0117951/                       Trainspotting
# 3        4      1996  /title/tt0114814/                  The Usual Suspects
# 4        5      1996  /title/tt0108598/                  The Wrong Trousers
#
#    Date  RunTime                       Genre  Rating  Score    Votes   Gross  \
# 0  1977      121  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1  1994      142                       Drama     9.3   80.0  2529673   28.34
# 2  1996       93                       Drama     8.1   83.0   665213   16.50
# 3  1995      106       Crime, Drama, Mystery     8.5   77.0  1045626   23.34
# 4  1993       30    Animation, Short, Comedy     8.3    NaN    53316     NaN
#
#          Director           Cast1             Cast2               Cast3  \
# 0    George Lucas     Mark Hamill     Harrison Ford       Carrie Fisher
# 1  Frank Darabont     Tim Robbins    Morgan Freeman          Bob Gunton
# 2     Danny Boyle   Ewan McGregor      Ewen Bremner    Jonny Lee Miller
# 3    Bryan Singer    Kevin Spacey     Gabriel Byrne    Chazz Palminteri
# 4       Nick Park    Peter Sallis     Peter Hawkins                 NaN
#
#                Cast4
# 0      Alec Guinness
# 1     William Sadler
# 2       Kevin McKidd
# 3    Stephen Baldwin
# 4                NaN

# %%
# Similarly Let's say we want to just peak at the last five rows of our dataset we can then use .tail()
# Since our dataframe is in the varaible df we are asking it to show us the last five rows using df.tail(5)
df.tail(5)
# Out:
#       Ranking  IMDByear            IMDBlink                  Title  Date  \
# 6495      246      2021   /title/tt0058946/  The Battle of Algiers  1966
# 6496      247      2021   /title/tt0050783/      Nights of Cabiria  1957
# 6497      248      2021   /title/tt0093779/     The Princess Bride  1987
# 6498      249      2021   /title/tt7060344/             Raatchasan  2018
# 6499      250      2021  /title/tt10280296/           Sardar Udham  2021
#
#       RunTime                       Genre  Rating  Score   Votes  Gross  \
# 6495      121                  Drama, War     8.1   96.0   57995   0.06
# 6496      110                       Drama     8.1    NaN   47318   0.75
# 6497       98  Adventure, Family, Fantasy     8.1   77.0  416207  30.86
# 6498      170       Crime, Drama, Mystery     8.4    NaN   37474    NaN
# 6499      164     Biography, Crime, Drama     8.7    NaN   34889    NaN
#
#               Director              Cast1              Cast2           Cast3  \
# 6495  Gillo Pontecorvo     Brahim Hadjadj        Jean Martin     Yacef Saadi
# 6496  Federico Fellini   Giulietta Masina    François Périer    Franca Marzi
# 6497        Rob Reiner         Cary Elwes     Mandy Patinkin    Robin Wright
# 6498         Ram Kumar      Vishnu Vishal         Amala Paul      Radha Ravi
# 6499    Shoojit Sircar      Vicky Kaushal      Banita Sandhu     Shaun Scott
#
#                   Cast4
# 6495      Samia Kerbash
# 6496        Dorian Gray
# 6497     Chris Sarandon
# 6498    Sangili Murugan
# 6499      Stephen Hogan

# %% [markdown]
# ## Quick Data Overview

# %% [markdown]
# .info() is a good way to get a quick overveiw of your dataset. It provides the essential details such as the number of rows and columns, the number of non-null values, what type of data is in each column, and how much memory your DataFrame is using.
#
# We can immediedtly see missing vavlues for Score, Gross, Cast 3 and Cast 4 but more on that later.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500 entries, 0 to 6499
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ranking   6500 non-null   int64
#  1   IMDByear  6500 non-null   int64
#  2   IMDBlink  6500 non-null   object
#  3   Title     6500 non-null   object
#  4   Date      6500 non-null   int64
#  5   RunTime   6500 non-null   int64
#  6   Genre     6500 non-null   object
#  7   Rating    6500 non-null   float64
#  8   Score     5674 non-null   float64
#  9   Votes     6500 non-null   int64
#  10  Gross     5691 non-null   float64
#  11  Director  6500 non-null   object
#  12  Cast1     6500 non-null   object
#  13  Cast2     6500 non-null   object
#  14  Cast3     6492 non-null   object
#  15  Cast4     6492 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 812.6+ KB

# %% [markdown]
# # Task 1 : Import a JSON file instead of a CSV using Pandas

# %% [markdown]
# You maye use the json data being provided by the exchange rate api.
# - https://api.exchangerate-api.com/v4/latest/USD
#
# Before importing the data visit the above link to see the json format in it's raw format and later compare it to what it looks like in a pandas dataframe.

# %% [markdown]
# ## Data types

# %% [markdown]
# ### Checking data types

# %% [markdown]
# We've considered what data is there, but some is numbers, some is text, some are dates. What does **Pandas** think each one is? This is important because it will determine what we can do with the data in each column, how it will be sorted, and filtered etc...
#
# We can use
#
# ``df.dtypes``
#
# to see each columns data type. We see that some of them are **objects**, which is the Pandas type for strings or mixed values. We can load the data in again and tell it which columns represent dates, and it will automatically parse them is they are in a consistent format. This means we can do things like compare them (e.g. which one is earlier?), which is really useful for sorting.
#
# You will see the loading takes longer, as it has to parse the dates, and that afterwards the chosen columns are of the ``datetime64[ns]`` type

# %%
df.dtypes
# Out:
# Ranking       int64
# IMDByear      int64
# IMDBlink     object
# Title        object
# Date          int64
# RunTime       int64
# Genre        object
# Rating      float64
# Score       float64
# Votes         int64
# Gross       float64
# Director     object
# Cast1        object
# Cast2        object
# Cast3        object
# Cast4        object
# dtype: object

# %% [markdown]
# ### Loading and formating date types

# %% [markdown]
# - As we can see above that the column "Date" are being read as a object even though they contain date and time hence should be in the datetime format.
# - Refer to https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html for more information on other formats.

# %%
# Reloading the csv data and parsing the dates in the correct format.

df = pd.read_csv("data/imdbTop250.csv", parse_dates=["Date"])

# %%
df.dtypes
# Out:
# Ranking              int64
# IMDByear             int64
# IMDBlink            object
# Title               object
# Date        datetime64[ns]
# RunTime              int64
# Genre               object
# Rating             float64
# Score              float64
# Votes                int64
# Gross              float64
# Director            object
# Cast1               object
# Cast2               object
# Cast3               object
# Cast4               object
# dtype: object

# %% [markdown]
# ## Summarising Data

# %% [markdown]
# **Pandas** can also give us a summary of our data (6500 is a lot to look at ourselves!).
#
# ``df.describe(include = "all")``

# %%
df.describe()
# Out:
#            Ranking     IMDByear      RunTime       Rating        Score  \
# count  6500.000000  6500.000000  6500.000000  6500.000000  5674.000000
# mean    125.500000  2008.500000   125.603385     8.171431    84.247268
# std      72.173758     7.500577    31.138483     0.327116    10.053112
# min       1.000000  1996.000000    16.000000     5.500000    61.000000
# 25%      63.000000  2002.000000   104.000000     8.000000    77.000000
# 50%     125.500000  2008.500000   121.000000     8.100000    85.000000
# 75%     188.000000  2015.000000   138.000000     8.300000    92.000000
# max     250.000000  2021.000000   321.000000     9.300000   100.000000
#
#               Votes        Gross
# count  6.500000e+03  5691.000000
# mean   4.843501e+05    70.709617
# std    4.743856e+05   103.075729
# min    9.194000e+03     0.010000
# 25%    1.214630e+05     5.320000
# 50%    3.057770e+05    26.240000
# 75%    7.341210e+05    92.435000
# max    2.529673e+06   936.660000

# %% [markdown]
# If we don't put ``include = "all"``, then we will only get summary stastics for **numeric** columns.

# %%
df.describe(include = "all")
# Out:
# /var/folders/4l/xm5jn32j517d842_nfd4nvymkgphp6/T/ipykernel_96244/426132078.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe(include = "all")
#             Ranking     IMDByear           IMDBlink  \
# count   6500.000000  6500.000000               6500
# unique          NaN          NaN                744
# top             NaN          NaN  /title/tt0076759/
# freq            NaN          NaN                 26
# first           NaN          NaN                NaN
# last            NaN          NaN                NaN
# mean     125.500000  2008.500000                NaN
# std       72.173758     7.500577                NaN
# min        1.000000  1996.000000                NaN
# 25%       63.000000  2002.000000                NaN
# 50%      125.500000  2008.500000                NaN
# 75%      188.000000  2015.000000                NaN
# max      250.000000  2021.000000                NaN
#
#                                      Title                 Date      RunTime  \
# count                                 6500                 6500  6500.000000
# unique                                 742                  101          NaN
# top     Star Wars: Episode IV - A New Hope  1995-01-01 00:00:00          NaN
# freq                                    26                  225          NaN
# first                                  NaN  1920-01-01 00:00:00          NaN
# last                                   NaN  2021-01-01 00:00:00          NaN
# mean                                   NaN                  NaN   125.603385
# std                                    NaN                  NaN    31.138483
# min                                    NaN                  NaN    16.000000
# 25%                                    NaN                  NaN   104.000000
# 50%                                    NaN                  NaN   121.000000
# 75%                                    NaN                  NaN   138.000000
# max                                    NaN                  NaN   321.000000
#
#         Genre       Rating        Score         Votes        Gross  \
# count    6500  6500.000000  5674.000000  6.500000e+03  5691.000000
# unique    200          NaN          NaN           NaN          NaN
# top     Drama          NaN          NaN           NaN          NaN
# freq      535          NaN          NaN           NaN          NaN
# first     NaN          NaN          NaN           NaN          NaN
# last      NaN          NaN          NaN           NaN          NaN
# mean      NaN     8.171431    84.247268  4.843501e+05    70.709617
# std       NaN     0.327116    10.053112  4.743856e+05   103.075729
# min       NaN     5.500000    61.000000  9.194000e+03     0.010000
# 25%       NaN     8.000000    77.000000  1.214630e+05     5.320000
# 50%       NaN     8.100000    85.000000  3.057770e+05    26.240000
# 75%       NaN     8.300000    92.000000  7.341210e+05    92.435000
# max       NaN     9.300000   100.000000  2.529673e+06   936.660000
#
#                 Director            Cast1            Cast2            Cast3  \
# count               6500             6500             6500             6492
# unique               437              486              633              667
# top     Alfred Hitchcock   Robert De Niro    Harrison Ford    Carrie Fisher
# freq                 222              151               78               80
# first                NaN              NaN              NaN              NaN
# last                 NaN              NaN              NaN              NaN
# mean                 NaN              NaN              NaN              NaN
# std                  NaN              NaN              NaN              NaN
# min                  NaN              NaN              NaN              NaN
# 25%                  NaN              NaN              NaN              NaN
# 50%                  NaN              NaN              NaN              NaN
# 75%                  NaN              NaN              NaN              NaN
# max                  NaN              NaN              NaN              NaN
#
#                        Cast4
# count                   6492
# unique                   699
# top       Billy Dee Williams
# freq                      52
# first                    NaN
# last                     NaN
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN

# %% [markdown]
# When we run the code, we get a table of stats describing our data. We can see that alot of the stats that are number based dont return values for our **nominal** columns, which is fine. But things such as the most common, and number of unique entries are stil interesting.
#
# For example, 200 Genres are present and Drama is the most common one. We can also see the first film in our dataset is from  **1920-01-01 00:00:00**, and this works because we formatted it as a date, so Pandas is able to order them.

# %% [markdown]
# ## Selecting Columns

# %% [markdown]
# We can select a column using its name
#
# ``df["ColumnName"]``
#
# Or we can select a bunch of columns by passing an array
#
# ``df[["ColumnName1","ColumnName2"]]``
#
# This returns a smaller **Series** object with the results but we can also use
#
# ``result.values``

# %%
df["Title"]
# Out:
# 0       Star Wars: Episode IV - A New Hope
# 1                 The Shawshank Redemption
# 2                            Trainspotting
# 3                       The Usual Suspects
# 4                       The Wrong Trousers
#                        ...
# 6495                 The Battle of Algiers
# 6496                     Nights of Cabiria
# 6497                    The Princess Bride
# 6498                            Raatchasan
# 6499                          Sardar Udham
# Name: Title, Length: 6500, dtype: object

# %%
df[["Title","Genre"]]
# Out:
#                                    Title                       Genre
# 0     Star Wars: Episode IV - A New Hope  Action, Adventure, Fantasy
# 1               The Shawshank Redemption                       Drama
# 2                          Trainspotting                       Drama
# 3                     The Usual Suspects       Crime, Drama, Mystery
# 4                     The Wrong Trousers    Animation, Short, Comedy
# ...                                  ...                         ...
# 6495               The Battle of Algiers                  Drama, War
# 6496                   Nights of Cabiria                       Drama
# 6497                  The Princess Bride  Adventure, Family, Fantasy
# 6498                          Raatchasan       Crime, Drama, Mystery
# 6499                        Sardar Udham     Biography, Crime, Drama
#
# [6500 rows x 2 columns]

# %%
#select column and get it back as an array of values
df["Genre"].values
# Out:
# array(['Action, Adventure, Fantasy', 'Drama', 'Drama', ...,
#        'Adventure, Family, Fantasy', 'Crime, Drama, Mystery',
#        'Biography, Crime, Drama'], dtype=object)

# %% [markdown]
# For more information on the differnce between lists and arrays check out https://www.geeksforgeeks.org/difference-between-list-and-array-in-python/

# %% [markdown]
# ## Counting Columns

# %% [markdown]
# We can get counts to see what the most prevalent combinations of categories are.
# - Here, for the type of films, we can see **Crime** and **Drama** are the most common. This is a good way for us to get a feel for all the different most popular combinations of Genres.
#
# ``df[["Category","SubCategoryName"]].value_counts()``

# %%
df[["Title","Genre"]].value_counts()
# Out:
# Title                                           Genre
# Once Upon a Time in America                     Crime, Drama                    26
# 12 Angry Men                                    Crime, Drama                    26
# Psycho                                          Horror, Mystery, Thriller       26
# Star Wars: Episode V - The Empire Strikes Back  Action, Adventure, Fantasy      26
# Star Wars: Episode VI - Return of the Jedi      Action, Adventure, Fantasy      26
#                                                                                 ..
# Pump Up the Volume                              Comedy, Drama, Music             1
# Priest                                          Drama, Romance                   1
# Portrait of a Lady on Fire                      Drama, Romance                   1
# Pleasantville                                   Comedy, Drama, Fantasy           1
# Zootopia                                        Animation, Adventure, Comedy     1
# Length: 744, dtype: int64

# %% [markdown]
# ## Filtering

# %% [markdown]
# As well as picking whole columns, we can also pick columns that fit certain parameters, using **filtering**. To do this we pick columns that equal a certain value
#
# ``df[df["Director"]=="George Lucas"]``

# %%
df[df["Director"]=="George Lucas"]
# Out:
#       Ranking  IMDByear           IMDBlink  \
# 0           1      1996  /title/tt0076759/
# 251         2      1997  /title/tt0076759/
# 502         3      1998  /title/tt0076759/
# 721       222      1998  /title/tt0069704/
# 756         7      1999  /title/tt0076759/
# 1007        8      2000  /title/tt0076759/
# 1257        8      2001  /title/tt0076759/
# 1508        9      2002  /title/tt0076759/
# 1759       10      2003  /title/tt0076759/
# 2009       10      2004  /title/tt0076759/
# 2257        8      2005  /title/tt0076759/
# 2493      244      2005  /title/tt0121766/
# 2510       11      2006  /title/tt0076759/
# 2761       12      2007  /title/tt0076759/
# 3011       12      2008  /title/tt0076759/
# 3261       12      2009  /title/tt0076759/
# 3513       14      2010  /title/tt0076759/
# 3766       17      2011  /title/tt0076759/
# 4015       16      2012  /title/tt0076759/
# 4266       17      2013  /title/tt0076759/
# 4519       20      2014  /title/tt0076759/
# 4768       19      2015  /title/tt0076759/
# 5019       20      2016  /title/tt0076759/
# 5269       20      2017  /title/tt0076759/
# 5521       22      2018  /title/tt0076759/
# 5774       25      2019  /title/tt0076759/
# 6024       25      2020  /title/tt0076759/
# 6276       27      2021  /title/tt0076759/
#
#                                              Title       Date  RunTime  \
# 0               Star Wars: Episode IV - A New Hope 1977-01-01      121
# 251             Star Wars: Episode IV - A New Hope 1977-01-01      121
# 502             Star Wars: Episode IV - A New Hope 1977-01-01      121
# 721                              American Graffiti 1973-01-01      110
# 756             Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1007            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1257            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1508            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1759            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2009            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2257            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2493  Star Wars: Episode III - Revenge of the Sith 2005-01-01      140
# 2510            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2761            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3011            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3261            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3513            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3766            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4015            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4266            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4519            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4768            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5019            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5269            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5521            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5774            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 6024            Star Wars: Episode IV - A New Hope 1977-01-01      121
# 6276            Star Wars: Episode IV - A New Hope 1977-01-01      121
#
#                            Genre  Rating  Score    Votes   Gross  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 251   Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 502   Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 721                Comedy, Drama     7.4   97.0    87100  115.00
# 756   Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1007  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1257  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1508  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1759  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2009  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2257  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2493  Action, Adventure, Fantasy     7.5   68.0   750330  380.26
# 2510  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2761  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3011  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3261  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3513  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3766  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4015  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4266  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4519  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4768  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5019  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5269  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5521  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5774  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 6024  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 6276  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
#
#           Director                Cast1              Cast2            Cast3  \
# 0     George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 251   George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 502   George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 721   George Lucas     Richard Dreyfuss         Ron Howard      Paul Le Mat
# 756   George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 1007  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 1257  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 1508  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 1759  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 2009  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 2257  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 2493  George Lucas   Hayden Christensen    Natalie Portman    Ewan McGregor
# 2510  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 2761  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 3011  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 3261  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 3513  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 3766  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 4015  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 4266  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 4519  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 4768  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 5019  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 5269  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 5521  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 5774  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 6024  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
# 6276  George Lucas          Mark Hamill      Harrison Ford    Carrie Fisher
#
#                        Cast4
# 0              Alec Guinness
# 251            Alec Guinness
# 502            Alec Guinness
# 721     Charles Martin Smith
# 756            Alec Guinness
# 1007           Alec Guinness
# 1257           Alec Guinness
# 1508           Alec Guinness
# 1759           Alec Guinness
# 2009           Alec Guinness
# 2257           Alec Guinness
# 2493       Samuel L. Jackson
# 2510           Alec Guinness
# 2761           Alec Guinness
# 3011           Alec Guinness
# 3261           Alec Guinness
# 3513           Alec Guinness
# 3766           Alec Guinness
# 4015           Alec Guinness
# 4266           Alec Guinness
# 4519           Alec Guinness
# 4768           Alec Guinness
# 5019           Alec Guinness
# 5269           Alec Guinness
# 5521           Alec Guinness
# 5774           Alec Guinness
# 6024           Alec Guinness
# 6276           Alec Guinness

# %%
df[df["Title"]=="Star Wars: Episode IV - A New Hope"]
# Out:
#       Ranking  IMDByear           IMDBlink  \
# 0           1      1996  /title/tt0076759/
# 251         2      1997  /title/tt0076759/
# 502         3      1998  /title/tt0076759/
# 756         7      1999  /title/tt0076759/
# 1007        8      2000  /title/tt0076759/
# 1257        8      2001  /title/tt0076759/
# 1508        9      2002  /title/tt0076759/
# 1759       10      2003  /title/tt0076759/
# 2009       10      2004  /title/tt0076759/
# 2257        8      2005  /title/tt0076759/
# 2510       11      2006  /title/tt0076759/
# 2761       12      2007  /title/tt0076759/
# 3011       12      2008  /title/tt0076759/
# 3261       12      2009  /title/tt0076759/
# 3513       14      2010  /title/tt0076759/
# 3766       17      2011  /title/tt0076759/
# 4015       16      2012  /title/tt0076759/
# 4266       17      2013  /title/tt0076759/
# 4519       20      2014  /title/tt0076759/
# 4768       19      2015  /title/tt0076759/
# 5019       20      2016  /title/tt0076759/
# 5269       20      2017  /title/tt0076759/
# 5521       22      2018  /title/tt0076759/
# 5774       25      2019  /title/tt0076759/
# 6024       25      2020  /title/tt0076759/
# 6276       27      2021  /title/tt0076759/
#
#                                    Title       Date  RunTime  \
# 0     Star Wars: Episode IV - A New Hope 1977-01-01      121
# 251   Star Wars: Episode IV - A New Hope 1977-01-01      121
# 502   Star Wars: Episode IV - A New Hope 1977-01-01      121
# 756   Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1007  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1257  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1508  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 1759  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2009  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2257  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2510  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 2761  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3011  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3261  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3513  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 3766  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4015  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4266  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4519  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 4768  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5019  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5269  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5521  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 5774  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 6024  Star Wars: Episode IV - A New Hope 1977-01-01      121
# 6276  Star Wars: Episode IV - A New Hope 1977-01-01      121
#
#                            Genre  Rating  Score    Votes   Gross  \
# 0     Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 251   Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 502   Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 756   Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1007  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1257  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1508  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1759  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2009  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2257  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2510  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 2761  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3011  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3261  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3513  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 3766  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4015  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4266  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4519  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 4768  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5019  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5269  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5521  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 5774  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 6024  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 6276  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
#
#           Director         Cast1            Cast2            Cast3  \
# 0     George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 251   George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 502   George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 756   George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 1007  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 1257  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 1508  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 1759  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 2009  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 2257  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 2510  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 2761  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 3011  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 3261  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 3513  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 3766  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 4015  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 4266  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 4519  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 4768  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 5019  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 5269  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 5521  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 5774  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 6024  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
# 6276  George Lucas   Mark Hamill    Harrison Ford    Carrie Fisher
#
#                 Cast4
# 0       Alec Guinness
# 251     Alec Guinness
# 502     Alec Guinness
# 756     Alec Guinness
# 1007    Alec Guinness
# 1257    Alec Guinness
# 1508    Alec Guinness
# 1759    Alec Guinness
# 2009    Alec Guinness
# 2257    Alec Guinness
# 2510    Alec Guinness
# 2761    Alec Guinness
# 3011    Alec Guinness
# 3261    Alec Guinness
# 3513    Alec Guinness
# 3766    Alec Guinness
# 4015    Alec Guinness
# 4266    Alec Guinness
# 4519    Alec Guinness
# 4768    Alec Guinness
# 5019    Alec Guinness
# 5269    Alec Guinness
# 5521    Alec Guinness
# 5774    Alec Guinness
# 6024    Alec Guinness
# 6276    Alec Guinness

# %% [markdown]
# ## Sorting

# %% [markdown]
# Strangely, this dataset isn't actually sorted by date, but we can do that using ``sort_values``. We tell **Pandas** which column we want to sort by, and this must be either a number, or an **ordinal** value (such as a date). We also say which direction we want to sort the results in, and this is useful if we want to get the top or bottom slice
#
# **Most recent 20**
#
# ``df.sort_values(by='Date', ascending=False)[:20]``
#
# **Earliest 20**
#
# ``df.sort_values(by='Date', ascending=True)[:20]``

# %%
df.head(5)
# Out:
#    Ranking  IMDByear           IMDBlink                               Title  \
# 0        1      1996  /title/tt0076759/  Star Wars: Episode IV - A New Hope
# 1        2      1996  /title/tt0111161/            The Shawshank Redemption
# 2        3      1996  /title/tt0117951/                       Trainspotting
# 3        4      1996  /title/tt0114814/                  The Usual Suspects
# 4        5      1996  /title/tt0108598/                  The Wrong Trousers
#
#         Date  RunTime                       Genre  Rating  Score    Votes  \
# 0 1977-01-01      121  Action, Adventure, Fantasy     8.6   90.0  1299781
# 1 1994-01-01      142                       Drama     9.3   80.0  2529673
# 2 1996-01-01       93                       Drama     8.1   83.0   665213
# 3 1995-01-01      106       Crime, Drama, Mystery     8.5   77.0  1045626
# 4 1993-01-01       30    Animation, Short, Comedy     8.3    NaN    53316
#
#     Gross        Director           Cast1             Cast2  \
# 0  322.74    George Lucas     Mark Hamill     Harrison Ford
# 1   28.34  Frank Darabont     Tim Robbins    Morgan Freeman
# 2   16.50     Danny Boyle   Ewan McGregor      Ewen Bremner
# 3   23.34    Bryan Singer    Kevin Spacey     Gabriel Byrne
# 4     NaN       Nick Park    Peter Sallis     Peter Hawkins
#
#                 Cast3              Cast4
# 0       Carrie Fisher      Alec Guinness
# 1          Bob Gunton     William Sadler
# 2    Jonny Lee Miller       Kevin McKidd
# 3    Chazz Palminteri    Stephen Baldwin
# 4                 NaN                NaN

# %%
df.sort_values(by='Date', ascending=False)[:20]
# Out:
#       Ranking  IMDByear            IMDBlink                    Title  \
# 6499      250      2021  /title/tt10280296/             Sardar Udham
# 6265       16      2021  /title/tt10872600/  Spider-Man: No Way Home
# 6432      183      2021   /title/tt1160419/                     Dune
# 6389      140      2021  /title/tt15097216/                 Jai Bhim
# 6358      109      2021  /title/tt10272386/               The Father
# 6159      160      2020   /title/tt2948372/                     Soul
# 6335       86      2021   /title/tt8503618/                 Hamilton
# 6050       51      2020   /title/tt8503618/                 Hamilton
# 6367      118      2021   /title/tt8579674/                     1917
# 6455      206      2021   /title/tt1950186/           Ford v Ferrari
# 6319       70      2021   /title/tt7286456/                    Joker
# 5912      163      2019   /title/tt7653254/           Marriage Story
# 6059       60      2020   /title/tt7286456/                    Joker
# 5879      130      2019   /title/tt1950186/           Ford v Ferrari
# 6075       76      2020   /title/tt4154796/        Avengers: Endgame
# 6029       30      2020   /title/tt6751668/                 Parasite
# 5926      177      2019   /title/tt4729430/                    Klaus
# 6409      160      2021   /title/tt4729430/                    Klaus
# 6101      102      2020   /title/tt8579674/                     1917
# 6325       76      2021   /title/tt4154796/        Avengers: Endgame
#
#            Date  RunTime                         Genre  Rating  Score  \
# 6499 2021-01-01      164       Biography, Crime, Drama     8.7    NaN
# 6265 2021-01-01      148    Action, Adventure, Fantasy     8.7   71.0
# 6432 2021-01-01      155      Action, Adventure, Drama     8.1   74.0
# 6389 2021-01-01      164                  Crime, Drama     9.3    NaN
# 6358 2020-01-01       97                Drama, Mystery     8.3   88.0
# 6159 2020-01-01      100  Animation, Adventure, Comedy     8.1   83.0
# 6335 2020-01-01      160     Biography, Drama, History     8.4   90.0
# 6050 2020-01-01      160     Biography, Drama, History     8.4   90.0
# 6367 2019-01-01      119            Action, Drama, War     8.3   78.0
# 6455 2019-01-01      152      Action, Biography, Drama     8.1   81.0
# 6319 2019-01-01      122        Crime, Drama, Thriller     8.4    NaN
# 5912 2019-01-01      137        Comedy, Drama, Romance     7.9   94.0
# 6059 2019-01-01      122        Crime, Drama, Thriller     8.4    NaN
# 5879 2019-01-01      152      Action, Biography, Drama     8.1   81.0
# 6075 2019-01-01      181      Action, Adventure, Drama     8.4   78.0
# 6029 2019-01-01      132       Comedy, Drama, Thriller     8.6   96.0
# 5926 2019-01-01       96  Animation, Adventure, Comedy     8.2   65.0
# 6409 2019-01-01       96  Animation, Adventure, Comedy     8.2   65.0
# 6101 2019-01-01      119            Action, Drama, War     8.3   78.0
# 6325 2019-01-01      181      Action, Adventure, Drama     8.4   78.0
#
#         Votes   Gross                               Director  \
# 6499    34889     NaN                         Shoojit Sircar
# 6265   401937     NaN                              Jon Watts
# 6432   452757     NaN                       Denis Villeneuve
# 6389   169008     NaN                          T.J. Gnanavel
# 6358   118928     NaN                         Florian Zeller
# 6159   295078     NaN              Pete Docter,  Kemp Powers
# 6335    81100     NaN                            Thomas Kail
# 6050    81100     NaN                            Thomas Kail
# 6367   524911  159.23                             Sam Mendes
# 6455   351575  117.62                          James Mangold
# 6319  1130322  335.45                          Todd Phillips
# 5912   284924    2.00                          Noah Baumbach
# 6059  1130322  335.45                          Todd Phillips
# 5879   351575  117.62                          James Mangold
# 6075   998598  858.37              Anthony Russo,  Joe Russo
# 6029   707824   53.37                           Bong Joon Ho
# 5926   136683     NaN  Sergio Pablos,  Carlos Martínez López
# 6409   136683     NaN  Sergio Pablos,  Carlos Martínez López
# 6101   524911  159.23                             Sam Mendes
# 6325   998598  858.37              Anthony Russo,  Joe Russo
#
#                       Cast1                 Cast2                   Cast3  \
# 6499          Vicky Kaushal         Banita Sandhu             Shaun Scott
# 6265            Tom Holland               Zendaya    Benedict Cumberbatch
# 6432      Timothée Chalamet      Rebecca Ferguson                 Zendaya
# 6389                 Suriya         Lijo Mol Jose              Manikandan
# 6358        Anthony Hopkins         Olivia Colman             Mark Gatiss
# 6159             Jamie Foxx              Tina Fey           Graham Norton
# 6335     Lin-Manuel Miranda          Phillipa Soo         Leslie Odom Jr.
# 6050     Lin-Manuel Miranda          Phillipa Soo         Leslie Odom Jr.
# 6367   Dean-Charles Chapman         George MacKay             Daniel Mays
# 6455             Matt Damon        Christian Bale            Jon Bernthal
# 6319        Joaquin Phoenix        Robert De Niro             Zazie Beetz
# 5912            Adam Driver    Scarlett Johansson             Julia Greer
# 6059        Joaquin Phoenix        Robert De Niro             Zazie Beetz
# 5879             Matt Damon        Christian Bale            Jon Bernthal
# 6075      Robert Downey Jr.           Chris Evans            Mark Ruffalo
# 6029           Kang-ho Song          Sun-kyun Lee           Yeo-jeong Cho
# 5926      Jason Schwartzman          J.K. Simmons           Rashida Jones
# 6409      Jason Schwartzman          J.K. Simmons           Rashida Jones
# 6101   Dean-Charles Chapman         George MacKay             Daniel Mays
# 6325      Robert Downey Jr.           Chris Evans            Mark Ruffalo
#
#                          Cast4
# 6499             Stephen Hogan
# 6265             Jacob Batalon
# 6432               Oscar Isaac
# 6389           Rajisha Vijayan
# 6358           Olivia Williams
# 6159              Rachel House
# 6335    Renée Elise Goldsberry
# 6050    Renée Elise Goldsberry
# 6367               Colin Firth
# 6455           Caitriona Balfe
# 6319            Frances Conroy
# 5912            Azhy Robertson
# 6059            Frances Conroy
# 5879           Caitriona Balfe
# 6075           Chris Hemsworth
# 6029              Woo-sik Choi
# 5926                Will Sasso
# 6409                Will Sasso
# 6101               Colin Firth
# 6325           Chris Hemsworth

# %%
df.sort_values(by='Date', ascending=True)[:20]
# Out:
#       Ranking  IMDByear           IMDBlink                        Title  \
# 2664      165      2006  /title/tt0010323/  The Cabinet of Dr. Caligari
# 2436      187      2005  /title/tt0010323/  The Cabinet of Dr. Caligari
# 2925      176      2007  /title/tt0010323/  The Cabinet of Dr. Caligari
# 4360      111      2013  /title/tt0012349/                      The Kid
# 4845       96      2015  /title/tt0012349/                      The Kid
# 6100      101      2020  /title/tt0012349/                      The Kid
# 4127      128      2012  /title/tt0012349/                      The Kid
# 5598       99      2018  /title/tt0012349/                      The Kid
# 3669      170      2010  /title/tt0012349/                      The Kid
# 6353      104      2021  /title/tt0012349/                      The Kid
# 3900      151      2011  /title/tt0012349/                      The Kid
# 5848       99      2019  /title/tt0012349/                      The Kid
# 3203      204      2008  /title/tt0012349/                      The Kid
# 5097       98      2016  /title/tt0012349/                      The Kid
# 4598       99      2014  /title/tt0012349/                      The Kid
# 5349      100      2017  /title/tt0012349/                      The Kid
# 3442      193      2009  /title/tt0012349/                      The Kid
# 1937      188      2003  /title/tt0013442/                    Nosferatu
# 907       158      1999  /title/tt0013442/                    Nosferatu
# 2929      180      2007  /title/tt0013442/                    Nosferatu
#
#            Date  RunTime                      Genre  Rating  Score   Votes  \
# 2664 1920-01-01       67  Horror, Mystery, Thriller     8.1    NaN   61561
# 2436 1920-01-01       67  Horror, Mystery, Thriller     8.1    NaN   61561
# 2925 1920-01-01       67  Horror, Mystery, Thriller     8.1    NaN   61561
# 4360 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 4845 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 6100 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 4127 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 5598 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 3669 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 6353 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 3900 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 5848 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 3203 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 5097 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 4598 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 5349 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 3442 1921-01-01       68      Comedy, Drama, Family     8.3    NaN  122477
# 1937 1922-01-01       94            Fantasy, Horror     7.9    NaN   93818
# 907  1922-01-01       94            Fantasy, Horror     7.9    NaN   93818
# 2929 1922-01-01       94            Fantasy, Horror     7.9    NaN   93818
#
#       Gross         Director             Cast1                Cast2  \
# 2664    NaN     Robert Wiene     Werner Krauss         Conrad Veidt
# 2436    NaN     Robert Wiene     Werner Krauss         Conrad Veidt
# 2925    NaN     Robert Wiene     Werner Krauss         Conrad Veidt
# 4360   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 4845   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 6100   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 4127   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 5598   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 3669   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 6353   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 3900   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 5848   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 3203   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 5097   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 4598   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 5349   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 3442   5.45  Charles Chaplin   Charles Chaplin       Edna Purviance
# 1937    NaN      F.W. Murnau       Max Schreck    Alexander Granach
# 907     NaN      F.W. Murnau       Max Schreck    Alexander Granach
# 2929    NaN      F.W. Murnau       Max Schreck    Alexander Granach
#
#                         Cast3             Cast4
# 2664          Friedrich Feher       Lil Dagover
# 2436          Friedrich Feher       Lil Dagover
# 2925          Friedrich Feher       Lil Dagover
# 4360            Jackie Coogan       Carl Miller
# 4845            Jackie Coogan       Carl Miller
# 6100            Jackie Coogan       Carl Miller
# 4127            Jackie Coogan       Carl Miller
# 5598            Jackie Coogan       Carl Miller
# 3669            Jackie Coogan       Carl Miller
# 6353            Jackie Coogan       Carl Miller
# 3900            Jackie Coogan       Carl Miller
# 5848            Jackie Coogan       Carl Miller
# 3203            Jackie Coogan       Carl Miller
# 5097            Jackie Coogan       Carl Miller
# 4598            Jackie Coogan       Carl Miller
# 5349            Jackie Coogan       Carl Miller
# 3442            Jackie Coogan       Carl Miller
# 1937    Gustav von Wangenheim    Greta Schröder
# 907     Gustav von Wangenheim    Greta Schröder
# 2929    Gustav von Wangenheim    Greta Schröder
